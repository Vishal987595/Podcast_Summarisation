# %%
import librosa
import matplotlib.pyplot as plt
data, sampling_rate = librosa.load('../data/VMP4732384152.mp3')

plt.figure(figsize=(15,5))
librosa.display.waveshow(data, sr=sampling_rate)
# Out:
# <class 'numpy.ndarray'> <class 'int'>

# %%
sampling_rate
# Out:
# 22050
